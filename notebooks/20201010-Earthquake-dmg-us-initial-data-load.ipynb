# %%
#TODO
#y hep -1 iloc ta olsun 
#unique id 1 de olsun

# %%
import pandas as pd

# %%
values = pd.read_csv('../data/raw/train_values.csv', sep = ',')
labels = pd.read_csv('../data/raw/train_labels.csv', sep = ',')

# %%
values.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_agriculture  \
# 0                      t               r  ...                             0
# ...

# %%
labels.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
df = values.merge(labels)

# %%
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_hotel  \
# 0                      t               r  ...                       0
# ...

# %%
df.to_csv('../data/interim/data_merged', sep = ';', index = False)

# %%
def separated_initial_data_load(values_file_path = '../data/raw/train_values.csv',
                                labels_file_path = '../data/raw/train_labels.csv', sep = ','):
    values = pd.read_csv('../data/raw/train_values.csv', sep = ',')
    labels = pd.read_csv('../data/raw/train_labels.csv', sep = ',')
    return values.merge(labels)

# %%
separated_initial_data_load()
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
import os
import sys
src_dir = os.path.join(os.getcwd(), '..', 'src')
sys.path.append(src_dir)

# %%
from data.load_data import separated_initial_data_load

# %%
separated_initial_data_load()
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
import pandas as pd
import sys

sys.path.append("..")
from src.data import load_data
#from src.data.categorize_data import get_drop_cols

# %%
load_data.separated_initial_data_load('data/raw/train_values.csv', 'data/raw/train_labels.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d5db9d25199c> in <module>
# ----> 1 load_data.separated_initial_data_load('data/raw/train_values.csv', 'data/raw/train_labels.csv')
#
# ~\Desktop\Projects\_playground\earthquake_dmg-drivendata-20201006\src\data\load_data.py in separated_initial_data_load(values_file_path, labels_file_path, sep)
#       4 def separated_initial_data_load(values_file_path='../data/raw/train_values.csv',
#       5                                 labels_file_path='../data/raw/train_labels.csv', sep=','):
# ----> 6     values = pd.read_csv(values_file_path, sep=sep)
#       7     labels = pd.read_csv(labels_file_path, sep=sep)
#       8     return values.merge(labels)
#
# ...
